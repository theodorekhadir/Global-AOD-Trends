# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span></li><li><span><a href="#Data" data-toc-modified-id="Data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data</a></span></li><li><span><a href="#Methods" data-toc-modified-id="Methods-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Methods</a></span><ul class="toc-item"><li><span><a href="#AERONET:-Ground-based-AOD-measurements" data-toc-modified-id="AERONET:-Ground-based-AOD-measurements-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>AERONET: Ground-based AOD measurements</a></span><ul class="toc-item"><li><span><a href="#Dataset" data-toc-modified-id="Dataset-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Dataset</a></span></li><li><span><a href="#Data-availability-requirement" data-toc-modified-id="Data-availability-requirement-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Data availability requirement</a></span></li><li><span><a href="#Regional-time-series-calculation" data-toc-modified-id="Regional-time-series-calculation-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Regional time series calculation</a></span></li><li><span><a href="#Mann-Kendal-trend-calculation" data-toc-modified-id="Mann-Kendal-trend-calculation-3.1.4"><span class="toc-item-num">3.1.4&nbsp;&nbsp;</span>Mann-Kendal trend calculation</a></span></li></ul></li><li><span><a href="#MODIS:-AOD-satellite-retrieval" data-toc-modified-id="MODIS:-AOD-satellite-retrieval-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>MODIS: AOD satellite retrieval</a></span></li><li><span><a href="#CMIP6-model-ensemble" data-toc-modified-id="CMIP6-model-ensemble-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>CMIP6 model ensemble</a></span></li><li><span><a href="#GFED4:-global-burned-area-satellite-retrieval" data-toc-modified-id="GFED4:-global-burned-area-satellite-retrieval-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>GFED4: global burned area satellite retrieval</a></span></li></ul></li><li><span><a href="#Results" data-toc-modified-id="Results-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Results</a></span><ul class="toc-item"><li><span><a href="#Multicomparison-of-regional-AOD-trends" data-toc-modified-id="Multicomparison-of-regional-AOD-trends-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Multicomparison of regional AOD trends</a></span></li><li><span><a href="#Seasonal-regional-trends" data-toc-modified-id="Seasonal-regional-trends-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Seasonal regional trends</a></span></li><li><span><a href="#Link-between-regional-AOD-and-biomass-burning-emission-trends" data-toc-modified-id="Link-between-regional-AOD-and-biomass-burning-emission-trends-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Link between regional AOD and biomass burning emission trends</a></span></li></ul></li><li><span><a href="#Discussion-and-outlook" data-toc-modified-id="Discussion-and-outlook-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Discussion and outlook</a></span></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Conclusion</a></span></li><li><span><a href="#References" data-toc-modified-id="References-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>References</a></span></li><li><span><a href="#Aknowlegments" data-toc-modified-id="Aknowlegments-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Aknowlegments</a></span></li></ul></div>

# %% [markdown]
# # Introduction

# %% [markdown]
# - Importance and role of aerosols in the climate system
#     - ARI
#     - ACI
#     - Air quality
# - Last 50 years, reduction of anthropogenic emissions to improve air quality and reduce GHG emissions.
# - It has been shown that a large part of the global warming has been shadowed by anthropogenic aerosol emissions (IPCC reports).
# - The impact of aerosols on the climate is local due to local emissions, short lived species, sparse distribution.
# - To better predict aerosol impact on climate, need to understand the evolution of regional aerosol amount in the atmosphere.
# - AOD is a good variable to study aerosol amount.
# - What does the litterature say about trend in AOD over land for the last 2 decades?
#     - Satellite retrievals
#     - Ground-based observations
#     - CMIP6 models
# - Questions:
#     - What is the regional AOD trend observed?
#     - How do GB, satellite compare to each other?
#     - Are ground-based station good to capture the trend?
#         - Where is it the best
#         - Do they provide additional information to MODIS? (see in litterature the purpose of AERONET)
#     - Do models agree on regional aerosol trend and how do they compare with observations
#     - Can biomass burning emissions explain a part of the regional trends observed?

# %% [markdown]
# # Data

# %% [markdown]
# # Methods

# %% [markdown]
# 3.2. Seasonal and annual long-term trend analysis
# Trend analysis was performed using the Mann-Kendall non-parametric statistical test on the seasonal and annual long-term trend for the historical period (1950–2011) and the future period (2012−2100) of temperature and precipitation time series. The Mann-Kendall test (Mann, 1945, Kendall, 1955) statistically assesses if there is a linear or non-linear upward or downward trend of the variable of interest over time. Mann-Kendall is a non-parametric test, therefore no assumption on the distribution of time series is required, however, there are some key assumptions associated to this test such as the requirement for observations, obtained over time, to be independent and identically distributed that means a very long record and non-stationarity of the time series (Mann, 1945, Kendall, 1955). Considering the uncertainty that comes from possible violations of this test, we applied the test on long-term seasonal total and maximum precipitation and seasonal mean and maximum temperature.

# %%
# !pip install pymannkendall
# Out:
# WARNING: The directory '/home/jovyan/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# ...

# %%
# !pip install global-land-mask
# Out:
# WARNING: The directory '/home/jovyan/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# ...
#      |████████████████████████████████| 1.8 MB 6.2 MB/s eta 0:00:01
# ...

# %%
import functions
import importlib
importlib.reload(functions)
# Out:
# <module 'functions' from '/data/jwd/main/034/597/34597070/working/jupyter/functions.py'>

# %% [markdown]
# Import all the functions and dictionnaries:
# - Dictionnaries
# - Data processing and analysis functions
# - Plotting functions

# %% [markdown]
# ## AERONET: Ground-based AOD measurements

# %%
n_day=6
n_month=2
n_season=2
list_ts, df_trend = functions.process_aeronet(n_day, n_month, n_season, functions.dict_regions)

# %%
df_trend
# Out:
#      lontitude   latitude altitude     slope     p_val intercept nb_yrs  \
# 0     109.6288    40.8517   1314.0  0.015451  0.063487   0.18326      8
# 1      130.891    -12.425     29.9 -0.012419  0.734095  0.181242      4
# 2    -28.02917   39.09109     15.2  0.002538   0.26551  0.083872      8
# 3      -149.88    70.4995      2.0  0.007149   0.26551  0.058589      8
# 4   -97.485619  36.605175    319.0  0.018149  0.734095  0.119597      4
# ..         ...        ...      ...       ...       ...       ...    ...
# 578  126.93479   37.56443     97.0 -0.019739  0.012731  0.561748     11
# 579 -114.58278  32.644138     63.0     0.005  0.371093  0.048323     10
# 580   -0.88235    41.6334    250.0 -0.001518  0.283131  0.123503     10
# 581   8.990233  13.776683    456.0 -0.065873  0.734095  0.626633      4
# 582     36.775     55.695    200.0 -0.002564    0.3223    0.1881     15
#
#     start_yr     region
# 0       2014      easia
# 1       2011  australia
# 2       2014       None
# ...

# %% [markdown]
# #### Number of station per region

# %%
functions.table_number_aeronet_stations(df_trend, functions.dict_regions)
# Out:
#        Region Number of stations
# 0      global                556
# 1      europe                127
# 2      russia                  6
# 3         nna                 42
# 4       easia                 77
# 5         sna                132
# 6       wasia                 32
# 7         nsa                 37
# 8   australia                 13
# 9         ssa                  8
# 10    nafrica                 61
# 11    safrica                 21

# %% [markdown]
# ### Seasonality

# %%
n_day = 6
n_month = 2
list_ts_djf, list_ts_mam, list_ts_jja, list_ts_son = functions.process_aeronet_season(
    n_day, n_month, functions.dict_regions)

# %% [markdown]
# ### Dataset
# - AOD measurements
# - Period and spatial covererage
# - Number of stations

# %% [markdown]
# ### Data availability requirement
# - Open all station measurements using the aeronet data stored in the cloud
# - Select the daily AOD at 500nm variable
# - Compute the yearly average of the daily time series, based on the following conditions (the conditions are used to get ride of the natural variability):
#     - Compute monthly averages if number of days of available data per month is > 15days
#     - Compute the seasonal average using the monthly average if the number of month per season is > 2 months
#     - Compute the yearly average using the seasonal average if a year contains all 4 seasons

# %% [markdown]
# - **list_ts**: each element of the list contains a yearly average time series from 1 station and the associated location of the station
#
# - **df_trend**: each row of the dataframe contains a station that fulfilled the requirements, and the columns are the mann-kendal trend for the years after 2000 and the parameters associated to the trend + the region in which the stations belong + the number of years of available yearly average

# %% [markdown]
# ### Regional time series calculation
# - We define rectangular regions over lands based on similar AOD trends found with MODIS AOD 550nm retrievals
#     - The regions are defined by the coordinates of the lower left and upper right corners of the rectangles, and can be found in a dictionnary in the functions file

# %%
functions.coordinates_regions(functions.dict_regions)
# Out:
#           Lower left lon Lower left lat Upper right lon Upper right lat
# global              -180            -90             180              90
# europe               -20             37              60              75
# russia                60             45             180              80
# nna                 -170             45             -55              78
# easia                100            -10             150              45
# sna                 -130             15             -60              45
# wasia                 60              0             100              45
# nsa                  -90            -35             -30              15
# australia            105            -45             165             -10
# ssa                  -80            -60             -55             -35
# nafrica              -25            -13              60              37
# safrica                0            -40              60             -13

# %% [markdown]
# ### Mann-Kendal trend calculation

# %% [markdown]
# - MK captures monotonic trend

# %% [markdown]
# ## MODIS: AOD satellite retrieval

# %% [markdown]
# - Read the data from 2000 to 2018
# - Calculate the yearly time series for each grid cell
# - Calculate the weighted AOD for weighted mean
# - Mask grid cells over sea to keep data over land only
# - Calculate the trend for each grid cell using the mann-kendall slope
# - Store the regional yearly time series (average of all grid cell time series per region) and calculate the associated mann-kendall trend

# %%
# read modis dataset for each year and concatenate them into one dataset
ds_modis = functions.read_MODIS_AOD_xr()
# compute the yearly mean for each grid cell
ds_modis_y = functions.yearly_mean_MODIS(ds_modis)
# apply a mask over ocean to keep only land grid cells
ds_modis_y_land = functions.mask_ocean(ds_modis_y, ds_modis_y.longitude, ds_modis_y.latitude)
# compute the MK trend for each gridd cell
ds_modis_y_land = functions.add_trend_MK_MODIS(ds_modis_y_land)

# %%
ds_modis_y_land = functions.mask_ocean(ds_modis_y, ds_modis_y.longitude, ds_modis_y.latitude)
ds_modis_y_land = functions.add_trend_MK_MODIS(ds_modis_y_land)

# %%
#list_trend_modis_region: MK trend (intercept and p_val) for each region
#list_ts_modis_region: mean time series of aod between all land grid cells for each region
#list_ts_modis_region_std: std time series of aod between all land grid cells for each region
list_trend_modis_region, list_ts_modis_region, list_ts_modis_region_std = functions.trend_meants_stdts_mk_modis_region(
    functions.dict_regions, ds_modis_y_land)

# %%
# print the trend per region
functions.table_modis_trend_region(list_trend_modis_region, functions.dict_regions)
# Out:
#        region slope (/yr)     p_val intercept relative_slope (%/yr)
# 0      global    0.000124  0.779566  0.219246              0.056402
# 1      europe   -0.000586  0.262911  0.198054             -0.296118
# 2      russia    0.002471  0.207857  0.166345              1.485417
# 3         nna    0.003417   0.01177  0.126964              2.691541
# 4       easia   -0.000425  0.888706  0.373702             -0.113666
# 5         sna   -0.001275  0.025151  0.176106             -0.723907
# 6       wasia     0.00363  0.000067  0.340616               1.06562
# 7         nsa   -0.001787  0.183699  0.189925             -0.940811
# 8   australia   -0.000083  0.779566  0.033177             -0.251051
# 9         ssa    0.000947   0.05009  0.091114               1.03938
# 10    nafrica    0.001435  0.107543   0.31552              0.454872
# 11    safrica   -0.000046  0.833735  0.120218             -0.038202

# %% [markdown]
# ## CMIP6 model ensemble

# %% [markdown]
# ## GFED4: global burned area satellite retrieval

# %%
ds_ba = functions.process_ba()

# %% [markdown]
# # Results

# %% [markdown]
# ## Multicomparison of regional AOD trends

# %%
functions.figure1_regional_AOD_trends(
    list_ts, ds_modis_y_land,list_trend_modis_region, list_ts_modis_region, 
    list_ts_modis_region_std, 2, functions.dict_regions, functions.dict_regions_sub)

# %%
functions.figure1_regional_AOD_trends(
    list_ts, ds_modis_y_land,list_trend_modis_region, list_ts_modis_region, 
    list_ts_modis_region_std, 1, functions.dict_regions, functions.dict_regions_sub)

# %% [markdown]
# ## Seasonal regional trends

# %% [markdown]
# #### AERONET

# %%
functions.figure2_regional_seasonal_AOD_trends(
    list_ts_djf, list_ts_mam, list_ts_jja, 
    list_ts_son, functions.dict_regions, functions.dict_regions_sub)

# %% [markdown]
# - Larger AOD during summer (JJA in the northern hemisphere, SON in the southern hemisphere) caused by?:
#     - less precipitation during summer
#     - more biomass burning
# - The global AOD over land for AERONET station is biased by inhomogeneous sampling -> check MODIS.
# - In some region, the trend changes a lot based on the season.

# %% [markdown]
# #### MODIS

# %% [markdown]
# ## Link between regional AOD and biomass burning emission trends

# %% [markdown]
# #### Regional trend in burned area

# %%
list_ts_region_burned_area_surface, list_ts_region_burned_area_ratio = functions.figure3_regional_burned_area_trend(
    ds_ba, functions.dict_regions, functions.dict_regions_sub)

# %% [markdown]
# #### Correlation yearly AOD and burned area

# %%
functions.figure4_corr_aod_ba(list_ts_region_burned_area_ratio, 
                        list_ts_modis_region, functions.dict_regions, functions.dict_regions_sub)

# %% [markdown]
# # Discussion and outlook

# %% [markdown]
# # Conclusion

# %% [markdown]
# # References

# %% [markdown]
# # Aknowlegments
